# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

# %%
detected_face = DeepFace.detectFace("D:/_data/MJ/mjmj.jpg")
detected_face.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(detected_face)

# %%
base_img = cv2.imread("D:/_data/MJ/mjmj.jpg")

# %%
plt.imshow(base_img[:, :, ::-1])

# %%
from retinaface import RetinaFace
import math
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
img_path = 'D:/_data/MJ/MJ2.png'

# %%
img = cv2.imread(img_path)

# %%
resp = RetinaFace.detect_faces(img_path = img_path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12952/4060179498.py in <module>
# ----> 1 resp = RetinaFace.detect_faces(img_path = img_path)
#
# C:\ProgramData\Anaconda3\lib\site-packages\retinaface\RetinaFace.py in detect_faces(img_path, threshold, model, allow_upscaling)
#      66
#      67     if model is None:
# ---> 68         model = build_model()
#      69
#      70     #---------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\retinaface\RetinaFace.py in build_model()
#      32
#      33         model = tf.function(
# ---> 34             retinaface_model.build_model(),
#      35             input_signature=(tf.TensorSpec(shape=[None, None, None, 3], dtype=np.float32),)
#      36         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\retinaface\model\retinaface_model.py in build_model()
#     676                                                    face_rpn_landmark_pred_stride8
#     677                                                    ])
# --> 678     model = load_weights(model)
#     679
#     680     return model
#
# C:\ProgramData\Anaconda3\lib\site-packages\retinaface\model\retinaface_model.py in load_weights(model)
#      46             + " and copy it to the ", exact_file, "manually.")
#      47
# ---> 48     model.load_weights(exact_file)
#      49
#      50     return model
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2312           'first, then load the weights.')
#    2313     self._assert_weights_created()
# -> 2314     with h5py.File(filepath, 'r') as f:
#    2315       if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2316         f = f['model_weights']
#
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     422             with phil:
#     423                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 424                 fid = make_fid(name, mode, userblock_size,
#     425                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     426                                fs_persist=fs_persist, fs_threshold=fs_threshold),
#
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     188         if swmr and swmr_support:
#     189             flags |= h5f.ACC_SWMR_READ
# --> 190         fid = h5f.open(name, flags, fapl=fapl)
#     191     elif mode == 'r+':
#     192         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (truncated file: eof = 61332196, sblock->base_addr = 0, stored_eof = 118667368)

# %%
resp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13896/2346945487.py in <module>
# ----> 1 resp
#
# NameError: name 'resp' is not defined
